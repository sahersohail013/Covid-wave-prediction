# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 



# %matplotlib inline
pd.pandas.set_option('display.max_columns',None)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
dataframe = pd.read_csv('owid-covid-data.csv')

# %%
dataframe.shape
# Out:
# (99105, 60)

# %%
dataframe.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                    0.026                  0.026
# 1                    0.026                  0.000
# 2                    0.026                  0.000
# 3                    0.026                  0.000
# 4                    0.026                  0.000
#
#    new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
#
#    new_deaths_per_million  new_deaths_smoothed_per_million  reproduction_rate  \
# 0                     NaN                              NaN                NaN
# 1                     NaN                              NaN                NaN
# 2                     NaN                              NaN                NaN
# 3                     NaN                              NaN                NaN
# 4                     NaN                              NaN                NaN
#
#    icu_patients  icu_patients_per_million  hosp_patients  \
# 0           NaN                       NaN            NaN
# 1           NaN                       NaN            NaN
# 2           NaN                       NaN            NaN
# 3           NaN                       NaN            NaN
# 4           NaN                       NaN            NaN
#
#    hosp_patients_per_million  weekly_icu_admissions  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
#
#    weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
#
#    weekly_hosp_admissions_per_million  new_tests  total_tests  \
# 0                                 NaN        NaN          NaN
# 1                                 NaN        NaN          NaN
# 2                                 NaN        NaN          NaN
# 3                                 NaN        NaN          NaN
# 4                                 NaN        NaN          NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  positive_rate  tests_per_case tests_units  \
# 0                              NaN            NaN             NaN         NaN
# 1                              NaN            NaN             NaN         NaN
# 2                              NaN            NaN             NaN         NaN
# 3                              NaN            NaN             NaN         NaN
# 4                              NaN            NaN             NaN         NaN
#
#    total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0                 NaN                NaN                      NaN
# 1                 NaN                NaN                      NaN
# 2                 NaN                NaN                      NaN
# 3                 NaN                NaN                      NaN
# 4                 NaN                NaN                      NaN
#
#    new_vaccinations  new_vaccinations_smoothed  \
# 0               NaN                        NaN
# 1               NaN                        NaN
# 2               NaN                        NaN
# 3               NaN                        NaN
# 4               NaN                        NaN
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  new_vaccinations_smoothed_per_million  \
# 0                                  NaN                                    NaN
# 1                                  NaN                                    NaN
# 2                                  NaN                                    NaN
# 3                                  NaN                                    NaN
# 4                                  NaN                                    NaN
#
#    stringency_index  population  population_density  median_age  \
# 0              8.33  38928341.0              54.422        18.6
# 1              8.33  38928341.0              54.422        18.6
# 2              8.33  38928341.0              54.422        18.6
# 3              8.33  38928341.0              54.422        18.6
# 4              8.33  38928341.0              54.422        18.6
#
#    aged_65_older  aged_70_older  gdp_per_capita  extreme_poverty  \
# 0          2.581          1.337        1803.987              NaN
# 1          2.581          1.337        1803.987              NaN
# 2          2.581          1.337        1803.987              NaN
# 3          2.581          1.337        1803.987              NaN
# 4          2.581          1.337        1803.987              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                597.029                 9.59             NaN           NaN
# 1                597.029                 9.59             NaN           NaN
# 2                597.029                 9.59             NaN           NaN
# 3                597.029                 9.59             NaN           NaN
# 4                597.029                 9.59             NaN           NaN
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                  37.746                         0.5            64.83
# 1                  37.746                         0.5            64.83
# 2                  37.746                         0.5            64.83
# 3                  37.746                         0.5            64.83
# 4                  37.746                         0.5            64.83
#
#    human_development_index  excess_mortality
# 0                    0.511               NaN
# 1                    0.511               NaN
# 2                    0.511               NaN
# 3                    0.511               NaN
# 4                    0.511               NaN

# %%
dataframe.isnull().sum()
# Out:
# iso_code                                     0
# continent                                 4651
# location                                     0
# date                                         0
# total_cases                               3526
# new_cases                                 3529
# new_cases_smoothed                        4539
# total_deaths                             13644
# new_deaths                               13488
# new_deaths_smoothed                       4539
# total_cases_per_million                   4035
# new_cases_per_million                     4038
# new_cases_smoothed_per_million            5043
# total_deaths_per_million                 14140
# new_deaths_per_million                   13984
# new_deaths_smoothed_per_million           5043
# reproduction_rate                        20218
# icu_patients                             89164
# icu_patients_per_million                 89164
# hosp_patients                            86755
# hosp_patients_per_million                86755
# weekly_icu_admissions                    98231
# weekly_icu_admissions_per_million        98231
# weekly_hosp_admissions                   97559
# weekly_hosp_admissions_per_million       97559
# new_tests                                54604
# total_tests                              54921
# total_tests_per_thousand                 54921
# new_tests_per_thousand                   54604
# new_tests_smoothed                       47361
# new_tests_smoothed_per_thousand          47361
# positive_rate                            50808
# tests_per_case                           51406
# tests_units                              45703
# total_vaccinations                       82886
# people_vaccinated                        83684
# people_fully_vaccinated                  86550
# new_vaccinations                         85582
# new_vaccinations_smoothed                70992
# total_vaccinations_per_hundred           82886
# people_vaccinated_per_hundred            83684
# people_fully_vaccinated_per_hundred      86550
# new_vaccinations_smoothed_per_million    70992
# stringency_index                         15619
# population                                 643
# population_density                        7009
# median_age                               10503
# aged_65_older                            11499
# aged_70_older                            10993
# gdp_per_capita                           10156
# extreme_poverty                          39067
# cardiovasc_death_rate                    10117
# diabetes_prevalence                       7858
# female_smokers                           29497
# male_smokers                             30514
# handwashing_facilities                   54397
# hospital_beds_per_thousand               18037
# life_expectancy                           4995
# human_development_index                   9970
# excess_mortality                         95602
# dtype: int64

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99105 entries, 0 to 99104
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               99105 non-null  object
#  1   continent                              94454 non-null  object
#  2   location                               99105 non-null  object
#  3   date                                   99105 non-null  object
#  4   total_cases                            95579 non-null  float64
#  5   new_cases                              95576 non-null  float64
#  6   new_cases_smoothed                     94566 non-null  float64
#  7   total_deaths                           85461 non-null  float64
#  8   new_deaths                             85617 non-null  float64
#  9   new_deaths_smoothed                    94566 non-null  float64
#  10  total_cases_per_million                95070 non-null  float64
#  11  new_cases_per_million                  95067 non-null  float64
#  12  new_cases_smoothed_per_million         94062 non-null  float64
#  13  total_deaths_per_million               84965 non-null  float64
#  14  new_deaths_per_million                 85121 non-null  float64
#  15  new_deaths_smoothed_per_million        94062 non-null  float64
#  16  reproduction_rate                      78887 non-null  float64
#  17  icu_patients                           9941 non-null   float64
#  18  icu_patients_per_million               9941 non-null   float64
#  19  hosp_patients                          12350 non-null  float64
#  20  hosp_patients_per_million              12350 non-null  float64
#  21  weekly_icu_admissions                  874 non-null    float64
#  22  weekly_icu_admissions_per_million      874 non-null    float64
#  23  weekly_hosp_admissions                 1546 non-null   float64
#  24  weekly_hosp_admissions_per_million     1546 non-null   float64
#  25  new_tests                              44501 non-null  float64
#  26  total_tests                            44184 non-null  float64
#  27  total_tests_per_thousand               44184 non-null  float64
#  28  new_tests_per_thousand                 44501 non-null  float64
#  29  new_tests_smoothed                     51744 non-null  float64
#  30  new_tests_smoothed_per_thousand        51744 non-null  float64
#  31  positive_rate                          48297 non-null  float64
#  32  tests_per_case                         47699 non-null  float64
#  33  tests_units                            53402 non-null  object
#  34  total_vaccinations                     16219 non-null  float64
#  35  people_vaccinated                      15421 non-null  float64
#  36  people_fully_vaccinated                12555 non-null  float64
#  37  new_vaccinations                       13523 non-null  float64
#  38  new_vaccinations_smoothed              28113 non-null  float64
#  39  total_vaccinations_per_hundred         16219 non-null  float64
#  40  people_vaccinated_per_hundred          15421 non-null  float64
#  41  people_fully_vaccinated_per_hundred    12555 non-null  float64
#  42  new_vaccinations_smoothed_per_million  28113 non-null  float64
#  43  stringency_index                       83486 non-null  float64
#  44  population                             98462 non-null  float64
#  45  population_density                     92096 non-null  float64
#  46  median_age                             88602 non-null  float64
#  47  aged_65_older                          87606 non-null  float64
#  48  aged_70_older                          88112 non-null  float64
#  49  gdp_per_capita                         88949 non-null  float64
#  50  extreme_poverty                        60038 non-null  float64
#  51  cardiovasc_death_rate                  88988 non-null  float64
#  52  diabetes_prevalence                    91247 non-null  float64
#  53  female_smokers                         69608 non-null  float64
#  54  male_smokers                           68591 non-null  float64
#  55  handwashing_facilities                 44708 non-null  float64
#  56  hospital_beds_per_thousand             81068 non-null  float64
#  57  life_expectancy                        94110 non-null  float64
#  58  human_development_index                89135 non-null  float64
#  59  excess_mortality                       3503 non-null   float64
# dtypes: float64(55), object(5)
# memory usage: 45.4+ MB

# %%
dataframe.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  9.557900e+04   95576.000000        94566.000000  8.546100e+04
# mean   1.056047e+06    6036.384092         6067.469109  2.861437e+04
# std    7.237234e+06   37789.730307        37560.151801  1.707167e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.252000e+03       2.000000            7.429000  5.400000e+01
# 50%    1.341400e+04      73.000000           91.857000  3.870000e+02
# 75%    1.428400e+05     805.000000          849.000000  3.756000e+03
# max    1.817645e+08  906017.000000       826388.429000  3.937050e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  85617.000000         94566.000000             95070.000000
# mean     146.585433           132.019648             13007.401042
# std      801.954380           745.427478             23953.301333
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000               259.342000
# 50%        2.000000             1.429000              1781.271000
# 75%       18.000000            14.429000             13540.557750
# max    18050.000000         14737.000000            179900.343000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           95067.000000                    94062.000000
# mean               76.043083                       76.381891
# std               200.159970                      158.849992
# min             -2153.437000                     -276.825000
# 25%                 0.211000                        1.288000
# 50%                 8.377000                       11.095500
# 75%                70.070500                       78.625000
# max             18293.675000                     4083.500000
#
#        total_deaths_per_million  new_deaths_per_million  \
# count              84965.000000            85121.000000
# mean                 288.020542                1.554566
# std                  521.250184                3.972520
# min                    0.001000              -76.445000
# 25%                    7.972000                0.000000
# 50%                   51.145000                0.134000
# 75%                  314.202000                1.340000
# max                 5820.087000              218.329000
#
#        new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# count                     94062.000000       78887.000000   9941.000000
# mean                          1.398890           1.003592   1065.584851
# std                           3.038689           0.351959   2894.257429
# min                         -10.921000          -0.020000      0.000000
# 25%                           0.000000           0.840000     32.000000
# 50%                           0.157000           1.010000    184.000000
# 75%                           1.285000           1.170000    718.000000
# max                          63.140000           5.860000  28889.000000
#
#        icu_patients_per_million  hosp_patients  hosp_patients_per_million  \
# count               9941.000000   12350.000000               12350.000000
# mean                  26.416827    4640.884615                 169.713402
# std                   27.143203   11882.840278                 210.746026
# min                    0.000000       0.000000                   0.000000
# 25%                    4.793000     118.000000                  23.611000
# 50%                   17.417000     665.000000                  81.932000
# 75%                   40.860000    2737.000000                 247.776250
# max                  192.735000  133214.000000                1532.573000
#
#        weekly_icu_admissions  weekly_icu_admissions_per_million  \
# count             874.000000                         874.000000
# mean              275.522217                          20.708383
# std               569.530279                          35.918362
# min                 0.000000                           0.000000
# 25%                10.795500                           1.775000
# 50%                51.742500                           8.719500
# 75%               225.064000                          22.825500
# max              4002.456000                         279.411000
#
#        weekly_hosp_admissions  weekly_hosp_admissions_per_million  \
# count             1546.000000                         1546.000000
# mean              3553.446574                          109.255226
# std              10832.170632                          215.426757
# min                  0.000000                            0.000000
# 25%                 50.500000                            9.452250
# 50%                326.077000                           41.770000
# 75%               1707.003750                          124.975750
# max             116323.000000                         2656.911000
#
#           new_tests   total_tests  total_tests_per_thousand  \
# count  4.450100e+04  4.418400e+04              44184.000000
# mean   4.790192e+04  7.726817e+06                309.569287
# std    1.759419e+05  3.374118e+07                727.664997
# min   -2.391720e+05  0.000000e+00                  0.000000
# 25%    1.647000e+03  1.596025e+05                 14.161250
# 50%    6.172000e+03  8.174680e+05                 71.496500
# 75%    2.391400e+04  3.431174e+06                292.816500
# max    3.740296e+06  4.661954e+08               9287.357000
#
#        new_tests_per_thousand  new_tests_smoothed  \
# count            44501.000000        5.174400e+04
# mean                 2.123176        4.547949e+04
# std                  5.972499        1.603150e+05
# min                -23.010000        0.000000e+00
# 25%                  0.143000        1.727000e+03
# 50%                  0.621000        6.529000e+03
# 75%                  1.949000        2.639175e+04
# max                327.086000        3.080396e+06
#
#        new_tests_smoothed_per_thousand  positive_rate  tests_per_case  \
# count                     51744.000000   48297.000000    47699.000000
# mean                          2.036451       0.088687      163.438106
# std                           5.074211       0.097167      891.410496
# min                           0.000000       0.000000        1.100000
# 25%                           0.141000       0.017000        7.700000
# 50%                           0.645000       0.053000       18.400000
# 75%                           2.003000       0.128000       56.900000
# max                          92.104000       0.933000    50000.000000
#
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        1.621900e+04       1.542100e+04             1.255500e+04
# mean         3.030863e+07       1.686719e+07             9.406503e+06
# std          1.598056e+08       8.905124e+07             4.521016e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.185505e+05       8.926000e+04             4.976700e+04
# 50%          9.040730e+05       6.349830e+05             3.821850e+05
# 75%          5.478036e+06       3.731221e+06             2.216806e+06
# max          3.001137e+09       1.806865e+09             8.338254e+08
#
#        new_vaccinations  new_vaccinations_smoothed  \
# count      1.352300e+04               2.811300e+04
# mean       6.678902e+05               3.198044e+05
# std        3.147912e+06               2.103319e+06
# min        0.000000e+00               0.000000e+00
# 25%        4.501500e+03               8.520000e+02
# 50%        2.566400e+04               6.923000e+03
# 75%        1.378035e+05               4.286600e+04
# max        4.739749e+07               4.258012e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    16219.000000                   15421.000000
# mean                        23.455175                      15.424363
# std                         30.369838                      18.286098
# min                          0.000000                       0.000000
# 25%                          2.200000                       1.840000
# 50%                         10.840000                       7.890000
# 75%                         33.050000                      22.980000
# max                        231.660000                     116.380000
#
#        people_fully_vaccinated_per_hundred  \
# count                         12555.000000
# mean                              9.609418
# std                              13.514808
# min                               0.000000
# 25%                               0.900000
# 50%                               4.080000
# 75%                              12.270000
# max                             115.270000
#
#        new_vaccinations_smoothed_per_million  stringency_index    population  \
# count                           28113.000000      83486.000000  9.846200e+04
# mean                             3206.529506         58.321166  1.248954e+08
# std                              4429.511080         21.047426  6.804884e+08
# min                                 0.000000          0.000000  4.700000e+01
# 25%                               366.000000         44.440000  2.225728e+06
# 50%                              1667.000000         60.190000  9.890400e+06
# 75%                              4555.000000         74.540000  3.481387e+07
# max                            118759.000000        100.000000  7.794799e+09
#
#        population_density    median_age  aged_65_older  aged_70_older  \
# count        92096.000000  88602.000000   87606.000000   88112.000000
# mean           385.770025     30.561608       8.789430       5.564491
# std           1796.733251      9.131547       6.211894       4.237690
# min              0.137000     15.100000       1.144000       0.526000
# 25%             36.253000     22.200000       3.466000       2.058000
# 50%             83.479000     29.700000       6.378000       3.871000
# 75%            209.588000     39.100000      14.312000       9.167000
# max          20546.766000     48.200000      27.049000      18.493000
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# count     88949.00000     60038.000000           88988.000000
# mean      19280.95764        13.405117             258.456375
# std       19988.21078        19.959849             119.014736
# min         661.24000         0.100000              79.370000
# 25%        4466.50700         0.600000             167.295000
# 50%       12951.83900         2.200000             242.648000
# 75%       27216.44500        21.200000             329.635000
# max      116935.60000        77.600000             724.417000
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count         91247.000000    69608.000000  68591.000000
# mean              7.924506       10.562945     32.695273
# std               4.141502       10.459557     13.484689
# min               0.990000        0.100000      7.700000
# 25%               5.310000        1.900000     21.600000
# 50%               7.110000        6.300000     31.400000
# 75%              10.080000       19.300000     41.100000
# max              30.530000       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            44708.000000                81068.000000     94110.000000
# mean                50.835035                    3.027619        73.235726
# std                 31.759124                    2.458790         7.558928
# min                  1.188000                    0.100000        53.280000
# 25%                 19.351000                    1.300000        67.920000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 83.241000                    3.861000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality
# count             89135.000000       3503.000000
# mean                  0.727372         18.243991
# std                   0.150355         36.030922
# min                   0.394000        -95.590000
# 25%                   0.602000          0.405000
# 50%                   0.748000          7.340000
# 75%                   0.848000         23.855000
# max                   0.957000        409.690000

# %%
## Here we will check the percentage of nan values present in each feature
## 1 -step make the list of features which has missing values
features_with_na=[features for features in dataframe.columns if dataframe[features].isnull().sum()>1]
## 2- step print the feature name and the percentage of missing values

for feature in features_with_na:
    print(feature, np.round(dataframe[feature].isnull().mean(), 4),  ' % missing values')
# Out:
# continent 0.0469  % missing values
# total_cases 0.0356  % missing values
# new_cases 0.0356  % missing values
# new_cases_smoothed 0.0458  % missing values
# total_deaths 0.1377  % missing values
# new_deaths 0.1361  % missing values
# new_deaths_smoothed 0.0458  % missing values
# total_cases_per_million 0.0407  % missing values
# new_cases_per_million 0.0407  % missing values
# new_cases_smoothed_per_million 0.0509  % missing values
# total_deaths_per_million 0.1427  % missing values
# new_deaths_per_million 0.1411  % missing values
# new_deaths_smoothed_per_million 0.0509  % missing values
# reproduction_rate 0.204  % missing values
# icu_patients 0.8997  % missing values
# icu_patients_per_million 0.8997  % missing values
# hosp_patients 0.8754  % missing values
# hosp_patients_per_million 0.8754  % missing values
# weekly_icu_admissions 0.9912  % missing values
# weekly_icu_admissions_per_million 0.9912  % missing values
# weekly_hosp_admissions 0.9844  % missing values
# weekly_hosp_admissions_per_million 0.9844  % missing values
# new_tests 0.551  % missing values
# total_tests 0.5542  % missing values
# total_tests_per_thousand 0.5542  % missing values
# new_tests_per_thousand 0.551  % missing values
# new_tests_smoothed 0.4779  % missing values
# new_tests_smoothed_per_thousand 0.4779  % missing values
# positive_rate 0.5127  % missing values
# tests_per_case 0.5187  % missing values
# tests_units 0.4612  % missing values
# total_vaccinations 0.8363  % missing values
# people_vaccinated 0.8444  % missing values
# people_fully_vaccinated 0.8733  % missing values
# new_vaccinations 0.8635  % missing values
# new_vaccinations_smoothed 0.7163  % missing values
# total_vaccinations_per_hundred 0.8363  % missing values
# people_vaccinated_per_hundred 0.8444  % missing values
# people_fully_vaccinated_per_hundred 0.8733  % missing values
# new_vaccinations_smoothed_per_million 0.7163  % missing values
# stringency_index 0.1576  % missing values
# population 0.0065  % missing values
# population_density 0.0707  % missing values
# median_age 0.106  % missing values
# aged_65_older 0.116  % missing values
# aged_70_older 0.1109  % missing values
# gdp_per_capita 0.1025  % missing values
# extreme_poverty 0.3942  % missing values
# cardiovasc_death_rate 0.1021  % missing values
# diabetes_prevalence 0.0793  % missing values
# female_smokers 0.2976  % missing values
# male_smokers 0.3079  % missing values
# handwashing_facilities 0.5489  % missing values
# hospital_beds_per_thousand 0.182  % missing values
# life_expectancy 0.0504  % missing values
# human_development_index 0.1006  % missing values
# excess_mortality 0.9647  % missing values

# %% [markdown]
# ### Relationship between features and total cases

# %%
for feature in features_with_na:
    data = dataframe.copy()
    
    # let's make a variable that indicates 1 if the observation was missing or zero otherwise
    data[feature] = np.where(data[feature].isnull(), 1, 0)
    
    # let's calculate the mean SalePrice where the information is missing or present
    data.groupby(feature)['total_cases'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# ### Numerical Features

# %%
# list of numerical variables
numerical_features = [feature for feature in dataframe.columns if dataframe[feature].dtypes != 'O']

print('Number of numerical variables: ', len(numerical_features))

# visualise the numerical variables
dataframe[numerical_features].head()
# Out:
# Number of numerical variables:  55
#    total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0          1.0        1.0                 NaN           NaN         NaN
# 1          1.0        0.0                 NaN           NaN         NaN
# 2          1.0        0.0                 NaN           NaN         NaN
# 3          1.0        0.0                 NaN           NaN         NaN
# 4          1.0        0.0                 NaN           NaN         NaN
#
#    new_deaths_smoothed  total_cases_per_million  new_cases_per_million  \
# 0                  NaN                    0.026                  0.026
# 1                  NaN                    0.026                  0.000
# 2                  NaN                    0.026                  0.000
# 3                  NaN                    0.026                  0.000
# 4                  NaN                    0.026                  0.000
#
#    new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
#
#    new_deaths_per_million  new_deaths_smoothed_per_million  reproduction_rate  \
# 0                     NaN                              NaN                NaN
# 1                     NaN                              NaN                NaN
# 2                     NaN                              NaN                NaN
# 3                     NaN                              NaN                NaN
# 4                     NaN                              NaN                NaN
#
#    icu_patients  icu_patients_per_million  hosp_patients  \
# 0           NaN                       NaN            NaN
# 1           NaN                       NaN            NaN
# 2           NaN                       NaN            NaN
# 3           NaN                       NaN            NaN
# 4           NaN                       NaN            NaN
#
#    hosp_patients_per_million  weekly_icu_admissions  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
#
#    weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
#
#    weekly_hosp_admissions_per_million  new_tests  total_tests  \
# 0                                 NaN        NaN          NaN
# 1                                 NaN        NaN          NaN
# 2                                 NaN        NaN          NaN
# 3                                 NaN        NaN          NaN
# 4                                 NaN        NaN          NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  positive_rate  tests_per_case  \
# 0                              NaN            NaN             NaN
# 1                              NaN            NaN             NaN
# 2                              NaN            NaN             NaN
# 3                              NaN            NaN             NaN
# 4                              NaN            NaN             NaN
#
#    total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0                 NaN                NaN                      NaN
# 1                 NaN                NaN                      NaN
# 2                 NaN                NaN                      NaN
# 3                 NaN                NaN                      NaN
# 4                 NaN                NaN                      NaN
#
#    new_vaccinations  new_vaccinations_smoothed  \
# 0               NaN                        NaN
# 1               NaN                        NaN
# 2               NaN                        NaN
# 3               NaN                        NaN
# 4               NaN                        NaN
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  new_vaccinations_smoothed_per_million  \
# 0                                  NaN                                    NaN
# 1                                  NaN                                    NaN
# 2                                  NaN                                    NaN
# 3                                  NaN                                    NaN
# 4                                  NaN                                    NaN
#
#    stringency_index  population  population_density  median_age  \
# 0              8.33  38928341.0              54.422        18.6
# 1              8.33  38928341.0              54.422        18.6
# 2              8.33  38928341.0              54.422        18.6
# 3              8.33  38928341.0              54.422        18.6
# 4              8.33  38928341.0              54.422        18.6
#
#    aged_65_older  aged_70_older  gdp_per_capita  extreme_poverty  \
# 0          2.581          1.337        1803.987              NaN
# 1          2.581          1.337        1803.987              NaN
# 2          2.581          1.337        1803.987              NaN
# 3          2.581          1.337        1803.987              NaN
# 4          2.581          1.337        1803.987              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                597.029                 9.59             NaN           NaN
# 1                597.029                 9.59             NaN           NaN
# 2                597.029                 9.59             NaN           NaN
# 3                597.029                 9.59             NaN           NaN
# 4                597.029                 9.59             NaN           NaN
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                  37.746                         0.5            64.83
# 1                  37.746                         0.5            64.83
# 2                  37.746                         0.5            64.83
# 3                  37.746                         0.5            64.83
# 4                  37.746                         0.5            64.83
#
#    human_development_index  excess_mortality
# 0                    0.511               NaN
# 1                    0.511               NaN
# 2                    0.511               NaN
# 3                    0.511               NaN
# 4                    0.511               NaN

# %% [markdown]
# #### Discrete Variable

# %%
## Numerical variables are usually of 2 type
## 1. Continous variable and Discrete Variables

discrete_feature=[feature for feature in numerical_features if len(data[feature].unique())<25 ]
print("Discrete Variables Count: {}".format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 1

# %%
discrete_feature
# Out:
# ['excess_mortality']

# %%
## Lets Find the realtionship between them and total cases

for feature in discrete_feature:
    data=dataframe.copy()
    data.groupby(feature)['total_cases'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('total_cases')
    plt.title(feature)
    plt.show()

# %% [markdown]
# #### Continuous Variable

# %%
continuous_feature=[feature for feature in numerical_features if feature not in discrete_feature]
print("Continuous feature Count {}".format(len(continuous_feature)))
# Out:
# Continuous feature Count 54

# %%
## Lets analyse the continuous values by creating histograms to understand the distribution

for feature in continuous_feature:
    dataset=data.copy()
    dataset[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %%
## We will be using logarithmic transformation

for feature in continuous_feature:
    dataset=data.copy()
    if 0 in dataset[feature].unique():
        pass
    else:
        dataset[feature]=np.log(dataset[feature])
        dataset['total_cases']=np.log(dataset['total_cases'])
        plt.scatter(dataset[feature],dataset['total_cases'])
        plt.xlabel(feature)
        plt.ylabel('total_cases')
        plt.title(feature)
        plt.show()

# %% [markdown]
# ### Outliers

# %%
for feature in continuous_feature:
    dataset=data.copy()
    if 0 in dataset[feature].unique():
        pass
    else:
        dataset[feature]=np.log(dataset[feature])
        dataset.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()
# Out:
# E:\MS DS\python\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ### Categorical Features

# %%
categorical_features=[feature for feature in dataframe.columns if dataframe[feature].dtypes=='O']
categorical_features
# Out:
# ['iso_code', 'continent', 'location', 'date', 'tests_units']

# %%
dataframe[categorical_features].head()
# Out:
#   iso_code continent     location        date tests_units
# 0      AFG      Asia  Afghanistan  2020-02-24         NaN
# 1      AFG      Asia  Afghanistan  2020-02-25         NaN
# 2      AFG      Asia  Afghanistan  2020-02-26         NaN
# 3      AFG      Asia  Afghanistan  2020-02-27         NaN
# 4      AFG      Asia  Afghanistan  2020-02-28         NaN

# %%
for feature in categorical_features:
    print('The feature is {} and number of categories are {}'.format(feature,len(dataframe[feature].unique())))
# Out:
# The feature is iso_code and number of categories are 230
# The feature is continent and number of categories are 7
# The feature is location and number of categories are 230
# The feature is date and number of categories are 546
# The feature is tests_units and number of categories are 5

# %%
for feature in categorical_features:
    dataset = dataframe.copy()
    dataset.groupby(feature)["total_cases"].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel("total_cases")
    plt.title(feature)
    plt.show()
